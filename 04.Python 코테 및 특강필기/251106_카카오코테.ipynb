# %%
import numpy as np
import pandas as pd
import json

# %% [markdown]
# 코딩테스트 프로그래머스
#
# https://school.programmers.co.kr/learn/courses/30/lessons/67256
#
# 카카오 인턴 키패드 누르기

# %%
def solution(numbers, hand):
    LefthandNumber = (1,4,7,"*")
    RightHandNumber = (3,6,9,"#")
    CenterHandNumber = (2,5,8,0)
    LeftHand = "*"
    RightHand = "#"
    result_str = ""
    for x in numbers:
        if x in LefthandNumber:
            LeftHand = x
            result_str += "L"
        elif x in RightHandNumber:
            RightHand = x
            result_str += "R"
        else:
            
            CenterDistance = CenterHandNumber.index(x)
            
            if LeftHand in LefthandNumber:
                LeftDistance = LefthandNumber.index(LeftHand)
                LeftDistance = abs(CenterDistance - LeftDistance) + 1
            else:
                LeftDistance = CenterHandNumber.index(LeftHand)
                LeftDistance = abs(CenterDistance - LeftDistance)
                
            if RightHand in RightHandNumber:
                RightDistance = RightHandNumber.index(RightHand)
                RightDistance = abs(CenterDistance - RightDistance) + 1
            else: 
                RightDistance = CenterHandNumber.index(RightHand) 
                RightDistance = abs(CenterDistance - RightDistance)

                
            if LeftDistance < RightDistance :
                LeftHand = x
                result_str += "L"
        
            elif LeftDistance > RightDistance :
                RightHand = x
                result_str += "R"        

            else:
                if hand == "left":
                    LeftHand = x
                    result_str += "L"
                else:
                    RightHand = x
                    result_str += "R"    
    
    return result_str

# %%
"LLR"+"L"
# Out:
# 'LLRL'

# %%
2 in (1,4,7,"*")
# Out:
# False

# %%
solution(	[7, 0, 8, 2, 8, 3, 1, 5, 7, 6, 2], "left")
# Out:
# 'LLLLLRLLLRL'

# %% [markdown]
# 딕셔러니를 사용하여 만든 방식

# %%
def solution(numbers, hand):
    answer = ''
    key_dict = {1:(0,0),2:(0,1),3:(0,2),
                4:(1,0),5:(1,1),6:(1,2),
                7:(2,0),8:(2,1),9:(2,2),
                '*':(3,0),0:(3,1),'#':(3,2)}

    left = [1,4,7]
    right = [3,6,9]
    lhand = '*'
    rhand = '#'
    for i in numbers:
        if i in left:
            answer += 'L'
            lhand = i
        elif i in right:
            answer += 'R'
            rhand = i
        else:
            curPos = key_dict[i]
            lPos = key_dict[lhand]
            rPos = key_dict[rhand]
            ldist = abs(curPos[0]-lPos[0]) + abs(curPos[1]-lPos[1])
            rdist = abs(curPos[0]-rPos[0]) + abs(curPos[1]-rPos[1])

            if ldist < rdist:
                answer += 'L'
                lhand = i
            elif ldist > rdist:
                answer += 'R'
                rhand = i
            else:
                if hand == 'left':
                    answer += 'L'
                    lhand = i
                else:
                    answer += 'R'
                    rhand = i

    return answer
