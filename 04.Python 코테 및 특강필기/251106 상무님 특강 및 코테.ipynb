# %%
import numpy as np
import pandas as pd
import json
import re

# %% [markdown]
# 상무님 특강 20251106
#
# ㅇK - mass 라고 하고 계속 이야기 하고 계시는데 해당 프로젝트를 현재 진행중이신가요? 네이버 지도나 티머니 회사도 연관 기업에 없는것 같아서 여쭤봅니다.
#
# K mass는 각종 앱을 모아둔 중계 앱이라 생각하면됨. 공공기관에서 앱들 모아서 하나의 서버에 관리 할테니 해당 어플리케이션을 사용하고 싶으면은 다른 사기업 앱과 연동하지말고 K mass를 사용하라.
#
#
# ㅇtagless 사업에서 기술중에 data를 실시간으로 내보내는데 데이터가 적게 발생하는 기술이 현재 존재한다.
#
# ㅇ자율주행의 수준이 생각보다 높음. 상용화까지 5년 예상. 자율주행분야도 전망이 좋다고 생각함

# %% [markdown]
# 상자 꺼내기 알고리즘 코테
#
# https://school.programmers.co.kr/learn/courses/30/lessons/389478

# %%
def solution(n, w, num):
    a = (n//w) - ((num-1) // w)
    if n % w == 0:
        result = a
    else:
        if ( n // w ) % 2 == ((num-1) // w) % 2:
            if  num % w == 0:
                result = a
            elif num % w <= n % w :
                result = a + 1
            else :
                result = a
    
        else:
           if  num % w == 0:
               result = a +1
           elif (num % w) + (n % w ) <= w:
                result = a 
           else:
               result = a +1
                
    return result

# %%
dic = {}
dic.update({1:(0,0)})
w = 3
z = 0
for y in rage(0,w):
    if z == 0 :
        dic.update({1:(0,0)})


        
    else:
print(dic)
# Out:
# {1: (0, 0)}

# %%
print(22 // 6)
22 % 6
# Out:
# 3
# 4

# %%
(8-1) // 6
# Out:
# 1

# %%
(8-1) % 6
# Out:
# 1

# %%
if 13  % 3 == 0 :
    return (13 // 3) - (( 6-1 ) // 3 )
else:    
    if (13 // 3) % 2 == 0 :
        c = 1
    elif (13 // 3) % 2 == 1:
        c = -1
    

    
    if ( 6-1 // 3 ) % 2 == 0:
        

    else:
# Out:
#   Cell In[25], line 9
#     if ( 6-1 // 3 ) % 2 == 0
#                             ^
# SyntaxError: expected ':'

# %%
n = 13
w = 3 
num = 6
result = 0
if n % w == 0:
    result = (n//w) - ((num-1) // w)

else:
    if ( n // w ) % 2 == ((num-1) // w) % 2:
        if num % w <= n % w :
            result = (n//w) - ((num-1) // w) + 1
        else :
            result = (n//w) - ((num-1) // w) 

    else:
       if  (num % w) + (n % w ) < w:
           result = (n//w) - ((num-1) // w) 
       else:
           result = (n//w) - ((num-1) // w)  + 1

return result
# Out:
#   Cell In[27], line 21
#     return result
#     ^
# SyntaxError: 'return' outside function

# %%
solution(13, 3, 6)
# Out:
# 4

# %%
#괜찮은 풀이

def solution(n, w, num):
    m1 = num%(w*2)
    m2 = ((w*2+1) - m1)%(w*2)
    # num 이상 n 이하의 수들 중 2*w로 나눈 나머지가 m1,m2인 것들의 수를 세면 된다.
    return len(range(num,n+1,w*2)) + len(range(num + (m2-m1)%(w*2), n+1, w*2))
