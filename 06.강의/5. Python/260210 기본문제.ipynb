# %%
"앙" // "나"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 "앙" // "나"
#
# TypeError: unsupported operand type(s) for //: 'str' and 'str'

# %%
"앙" + "나"
# Out:
# '앙나'

# %%
"ㅅ" + "ㅗ"
# Out:
# 'ㅅㅗ'

# %% [markdown]
# ### 어느 부분이 이해가 안되요??
# ### 어느 부분이 이해가 안되는거지??
# ### 어느 부분이 ??????????????????????????????

# %%
1 == 1 & 1 == 3
# Out:
# False
