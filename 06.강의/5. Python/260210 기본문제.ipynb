# %%
"앙" // "나"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 "앙" // "나"
#
# TypeError: unsupported operand type(s) for //: 'str' and 'str'

# %%
"앙" + "나"
# Out:
# '앙나'

# %%
"ㅅ" + "ㅗ"
# Out:
# 'ㅅㅗ'

# %% [markdown]
# ### 어느 부분이 이해가 안되요??
# ### 어느 부분이 이해가 안되는거지??
# ### 어느 부분이 ??????????????????????????????

# %%
1 == 1 & 1 == 3
# Out:
# False

# %% [markdown]
# ---
# ### 🔑 환경 설정
#
# npm:
#
#     'npm install'
#
# application.properties
#
# spring:
#
#   datasource:
#
#     'url: jdbc:postgres://localhost:5432/postgres'
#
#     'username: postgres'
#
#     'password: 1234'
#
# ---

# %% [markdown]
# 어떻게 하는걸까요????? 아까 선생님이 보여주던 markdown에서 해당 하는 부분만 코드 영역처럼 보여주던데요
