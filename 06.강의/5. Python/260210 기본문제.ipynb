# %%
"앙" // "나"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 "앙" // "나"
#
# TypeError: unsupported operand type(s) for //: 'str' and 'str'

# %%
"앙" + "나"
# Out:
# '앙나'

# %%
"ㅅ" + "ㅗ"
# Out:
# 'ㅅㅗ'

# %% [markdown]
# ### 어느 부분이 이해가 안되요??
# ### 어느 부분이 이해가 안되는거지??
# ### 어느 부분이 ??????????????????????????????

# %%
1 == 1 & 1 == 3
# Out:
# False

# %% [markdown]
# ---
# ### 🔑 환경 설정
#
# npm:
#
#     'npm install'
#
# application.properties
#
# spring:
#
#   datasource:
#
#     'url: jdbc:postgres://localhost:5432/postgres'
#
#     'username: postgres'
#
#     'password: 1234'
#
# ---

# %% [markdown]
# 어떻게 하는걸까요????? 아까 선생님이 보여주던 markdown에서 해당 하는 부분만 코드 영역처럼 보여주던데요

# %%
asian = "korean"

# %%
print(f"sdsdsd{asian}")

print("sdsdsd{}".format(asian))
# Out:
# sdsdsdkorean
# sdsdsdkorean

# %% [markdown]
# ------------------------------------------------------
# 0. [포도 딸기 사과 ]
# 1. [포도 키위 사과 ]
# 2. [포도 바나나 사과 ]
# 3. [포도 망고 사과 ]
#
# 무엇을 삭제하시겠습니까(번호)?

# %%
for x in range(5):
    print(x)
    print('x')
# Out:
# 0
# x
# 1
# x
# 2
# x
# 3
# x
# 4
# x

# %%
fruit = ['포도', '딸기', '사과']

# %%
fruit

# %%
fruit = ['포도', '딸기', '사과']
indexno = fruit.index('딸기')
del fruit[indexno]
print(fruit)
# Out:
# ['포도', '사과']

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
현재 리스트 를 반복문 돌린다.
    0. 첫번째 리스트 원소
    1. 두번째 리스트 원소
    2. 세번째 리스트 원소
# Out:
#   Cell In[14], line 1
#     현재 리스트 를 반복문 돌린다.
#        ^
# SyntaxError: invalid syntax
