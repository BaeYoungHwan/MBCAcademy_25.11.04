# %% [markdown]
# # CNN(Convolutional Neural Network)
# 인간의 시각 처리 방식을 모방하여 이미지와 영상 데이터를 분석하는 딥러닝 모델
#
# # RNN(자연어처리, 시계열처리)

# %%
# !pip install --upgrade tensorflow
# Out:
# ...
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# ...
#    ---------------------------------------- 0.0/332.0 MB ? eta -:--:--
#     --------------------------------------- 6.3/332.0 MB 50.3 MB/s eta 0:00:07
#     --------------------------------------- 7.6/332.0 MB 18.2 MB/s eta 0:00:18
#    -- ------------------------------------- 21.5/332.0 MB 34.1 MB/s eta 0:00:10
#    ---- ----------------------------------- 34.3/332.0 MB 41.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 48.2/332.0 MB 46.9 MB/s eta 0:00:07
#    ------- -------------------------------- 59.8/332.0 MB 48.0 MB/s eta 0:00:06
#    -------- ------------------------------- 70.5/332.0 MB 48.3 MB/s eta 0:00:06
#    ---------- ----------------------------- 84.4/332.0 MB 50.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 98.8/332.0 MB 52.2 MB/s eta 0:00:05
#    ------------ -------------------------- 110.4/332.0 MB 52.7 MB/s eta 0:00:05
# ...

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Input
# Out:
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %%
# Model 초기화

# 입력층 추가

# 합성곱 Layer

#

# %% [markdown]
# 우리 개발자들이 본인 DB에 연동 해서 할거에요
# Postgres
# 저번에 했던것 처럼 SQL 짜서 보내주고 DB 엑셀 만들면 되요
# 저 csv 파일은 예시 데이터 저거는 ERD
#
# SQL은 SQL
#
# 솔직히 설계서가 먼저인지
# DB가 먼저인지 모르겠어요
# 뭐 부터 하고 싶어요?
#
#
# 화면 설계서?
#
# DB 구축(3일)
# 3일이면 충분 하지 않나? 러프하게 잡았다고 생각했는데
# 진짜로
#
# 맞아요 저도 그래요
#
# 주제 선정 하고 3일 첫번째 DB 구축 후
# 어짜피 딥러닝 안 들을거잖아요
#
# OpenCV는 들을거에요?
# 자동차 인식
#
# 저는 굳이?
# 프로젝트 하면서 코드 보실거에요? 욕심있으면 봐도 되고
#
#
# 그러면 이번주에 주제 선정하고
#
# 본인도 이번주 다음주는 계속 공부 주간으로 잡고 프로젝트 파악하는 기간이라고 생각해요.
#
# 웹이랑 붙이는 머신러닝은 처음이니까 이번주 다음주는 계속 공부에 집중할려고 하거든요
#
# 그래서 웹도 재영씨랑 종석씨도 이번주 다음주 까지는 웹 개발 뚝딱 뚝딱 하게 그냥 설계서넘기면 개발 가능 할 수준까지 만들고 싶은 욕심
# 2주정도 소비해서
#
#
# 그리고 종석씨에게 웹 담당 맡길꺼고
# 4월 초중순에는 재영씨는 파이썬으로 넘어와서 작업 할거에요
# 4월 초중순 부터는 종석씨 혼자 웹담당
#
# 본인은 설계서 2주 DB구축 1주
# >> 3월 끝
#
# 4월 > 파이썬에서 사용하는 데이터 전처리
# 및 발표 자료 등 문서 작업 및 추가 설계서 및 추가 DB구축 및 SQL(데이터 전체 관리)
#
# 그리고 좀 있다가 5시에도 말을 할건데 혹시나 개발이 지연되면 개발집중기간 이라고 해서 다른 기간보다도 더 집중해서 개발하는 기간을 설정할거에요
#
# 그떄에는 우리 다같이 야근해서 그 기간중에 집중해서 해봅시다.
# >> 개발지연된 사람만 남는게 아니라 모든 팀원들이 남아서 문제해결을 위해 다같이 남는 기간
#
#
# 이런 기간은 없으면 좋겠지만 한번정도는 할 각오를 하는게 좋을거에요..
#
#
# 10분 남았어요
